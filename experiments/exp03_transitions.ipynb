# %% [markdown]
# # exp03 - regime transitions and extrapolation maps
#
# Stub for later work: mapping where in rho the cold extrapolation holds and where it breaks, with attention to the subcritical Hopf onset near rho = 24.74 and the amplitude error that dominates C1 at the sweep edges.

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'src'))
import numpy as np
import lorenz, reservoir, metrics, training
