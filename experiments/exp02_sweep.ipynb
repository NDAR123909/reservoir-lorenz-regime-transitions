# %% [markdown]
# # exp02 - hyperparameter and design sweeps (C2-C4)
#
# Stub. The C2-C4 sweeps are the next session's work and are intentionally not run here. C1 has to settle first: the gate is currently exhausted and the methodology is flagged for a section-10 revision, so sweeping on top of an unlocked configuration would be premature.
#
# When it runs, this notebook will vary the training-rho placement, the reference interval, and the parameter-channel encoding, holding the C1-locked values fixed.

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'src'))
import numpy as np
import lorenz, reservoir, metrics, training
